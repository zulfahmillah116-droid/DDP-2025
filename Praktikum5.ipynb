# %% [markdown]
# <a href="https://colab.research.google.com/github/zulfahmillah116-droid/DDP-2025/blob/main/Praktikum5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
namakendaraan =  "Beat Ember"
jeniskendaraan =  "motor"
cckendaraan =  200
warnakendaraan =  "Hitam"
rodakendaraan =  2

data_kendaraan = [
namakendaraan, jeniskendaraan, cckendaraan,
warnakendaraan, rodakendaraan
]
print (data_kendaraan)

hargakendaraan =  5000
tipekendaraan =  "metic"

data_kendaraan.append(hargakendaraan)
data_kendaraan.append(tipekendaraan)
print (data_kendaraan)

merekkendaraan =  "Honda"
data_kendaraan.insert( 2 ,merekkendaraan)
print (data_kendaraan)
# Out:
# ['Beat Ember', 'motor', 200, 'Hitam', 2]
# ['Beat Ember', 'motor', 200, 'Hitam', 2, 5000, 'metic']
# ['Beat Ember', 'motor', 'Honda', 200, 'Hitam', 2, 5000, 'metic']

# %%
pilihan = input (    """
Silakan pilih menu yang diinginkan
=====
1.Luas persegi
2.Luas lingkaran
3.Luas Segitiga
=====
Kirimkan angka saja,
jawaban = """    )

match pilihan:
 case "1":
  sisi = int(input("sisi = "))
  luas = sisi * sisi
  print(f"luas persegi dengan sisi {sisi} adalah {luas}")
  #luas persegi
 case "2" :
  jarijari = int(input("jarijari = "))
  luas = 3.14  * jarijari
  print(f"luas lingkaran dengan jarijari {jarijari} adalah {luas} ")
  #luas lingkaran #phi *jarijari**2
 case "3" :
  alas = int(input("alas = "))
  tinggi = int(input("tinggi = "))
  luas = (alas * tinggi)/2
  #luas segitiga
  #(alas *tinggi)/2 print ( "luas segitiga dengan alas {alas} tinggi {tinggi} adalah {luas}")
# Out:
#
# Silakan pilih menu yang diinginkan
# =====
# 1.Luas persegi
# 2.Luas lingkaran
# 3.Luas Segitiga
# =====
# Kirimkan angka saja,
# jawaban = 3
# alas = 3
# tinggi = 2
